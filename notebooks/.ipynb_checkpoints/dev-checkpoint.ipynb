# %%
import pandas as pd
import numpy as np

# %%
pokemon_df = pd.read_csv('../data/pokemon.csv')

# %%
pokemon_df
# Out:
#        #        Name  Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 0      1   Bulbasaur   Grass  Poison    318   45      49       49       65
# 1      2     Ivysaur   Grass  Poison    405   60      62       63       80
# 2      4  Charmander    Fire     NaN    309   39      52       43       60
# 3      5  Charmeleon    Fire     NaN    405   58      64       58       80
# 4      7    Squirtle   Water     NaN    314   44      48       65       50
# ..   ...         ...     ...     ...    ...  ...     ...      ...      ...
# 650  714      Noibat  Flying  Dragon    245   40      30       35       45
# 651  715     Noivern  Flying  Dragon    535   85      70       80       97
# 652  716     Xerneas   Fairy     NaN    680  126     131       95      131
# 653  717     Yveltal    Dark  Flying    680  126     131       95      131
# 654  721   Volcanion    Fire   Water    600   80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# ...

# %%
boolean_names = []
for name in pokemon_df['Name']:
    if name.find(' ') == -1:
        boolean_names.append(False)
    else:
        boolean_names.append(True)

# %%
dropped = pokemon_df.drop(
    pokemon_df.index[boolean_names])

# %%
dropped = pokemon_df.drop(labels=['#'], axis=1)

# %%
dropped
# Out:
#            Name  Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 0     Bulbasaur   Grass  Poison    318   45      49       49       65
# 1       Ivysaur   Grass  Poison    405   60      62       63       80
# 2    Charmander    Fire     NaN    309   39      52       43       60
# 3    Charmeleon    Fire     NaN    405   58      64       58       80
# 4      Squirtle   Water     NaN    314   44      48       65       50
# ..          ...     ...     ...    ...  ...     ...      ...      ...
# 650      Noibat  Flying  Dragon    245   40      30       35       45
# 651     Noivern  Flying  Dragon    535   85      70       80       97
# 652     Xerneas   Fairy     NaN    680  126     131       95      131
# 653     Yveltal    Dark  Flying    680  126     131       95      131
# 654   Volcanion    Fire   Water    600   80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 0         65     45           1      False
# ...

# %%
len(dropped)
# Out:
# 655

# %%
dropped.to_csv('../data/pokemon.csv')
